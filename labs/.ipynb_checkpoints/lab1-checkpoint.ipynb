# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd

# Параметры варианта 1
n1, n2 = 100, 100
m1_true, sigma1_true = 1, np.sqrt(2)
a2, b2 = -1, 1

# Генерация данных
X1 = stats.norm.rvs(loc=m1_true, scale=sigma1_true, size=n1)
X2 = stats.uniform.rvs(loc=a2, scale=(b2 - a2), size=n2)

# Просмотр первых значений
pd.DataFrame({'X1': X1[:10], 'X2': X2[:10]})
# Out:
#          X1        X2
# 0  0.330909 -0.455385
# 1  1.898162  0.528280
# 2  1.359437 -0.067809
# 3  0.309564  0.058908
# 4  2.594053  0.124385
# 5  0.373130 -0.738423
# 6  1.530126 -0.143083
# 7 -0.315383  0.822418
# 8  0.565812 -0.570610
# 9 -1.320233 -0.771727

# %%
desc_X1 = stats.describe(X1)
desc_X2 = stats.describe(X2)

mean_X1, var_X1, std_X1 = desc_X1.mean, desc_X1.variance, np.sqrt(desc_X1.variance)
mean_X2, var_X2, std_X2 = desc_X2.mean, desc_X2.variance, np.sqrt(desc_X2.variance)

table = pd.DataFrame({
    'СВ': ['X1', 'X2'],
    'Среднее': [mean_X1, mean_X2],
    'Дисперсия': [var_X1, var_X2],
    'СКО': [std_X1, std_X2],
    'Объем выборки': [n1, n2]
})
table
# Out:
#    СВ   Среднее  Дисперсия       СКО  Объем выборки
# 0  X1  1.097144   1.672557  1.293274            100
# 1  X2 -0.070666   0.370566  0.608741            100

# %%
alpha = 0.05

# Z-test (σ известна)
z_stat = (mean_X1 - m1_true) / (sigma1_true / np.sqrt(n1))
p_z = 2 * (1 - stats.norm.cdf(abs(z_stat)))

# t-test (σ неизвестна)
t_stat, p_t = stats.ttest_1samp(X1, popmean=m1_true)

# Chi-square test (дисперсия известна)
chi_stat_known = (n1 - 1) * var_X1 / 2
p_chi_known = 2 * min(stats.chi2.cdf(chi_stat_known, df=n1 - 1),
                      1 - stats.chi2.cdf(chi_stat_known, df=n1 - 1))

# Chi-square test (дисперсия неизвестна)
chi_stat_unknown = (n1 - 1) * var_X1 / np.var(X1)
p_chi_unknown = 2 * min(stats.chi2.cdf(chi_stat_unknown, df=n1 - 1),
                        1 - stats.chi2.cdf(chi_stat_unknown, df=n1 - 1))

pd.DataFrame({
    'Тест': ['Z-test', 't-test', 'Chi-square (σ изв.)', 'Chi-square (σ не изв.)'],
    'Статистика': [z_stat, t_stat, chi_stat_known, chi_stat_unknown],
    'p-value': [p_z, p_t, p_chi_known, p_chi_unknown],
    'Решение при α=0.05': [
        'H0 принимается' if p_z > alpha else 'H0 отвергается',
        'H0 принимается' if p_t > alpha else 'H0 отвергается',
        'H0 принимается' if p_chi_known > alpha else 'H0 отвергается',
        'H0 принимается' if p_chi_unknown > alpha else 'H0 отвергается'
    ]
})
# Out:
#                      Тест  Статистика   p-value Решение при α=0.05
# 0                  Z-test    0.686915  0.492136     H0 принимается
# 1                  t-test    0.751152  0.454343     H0 принимается
# 2     Chi-square (σ изв.)   82.791585  0.240616     H0 принимается
# 3  Chi-square (σ не изв.)  100.000000  0.905917     H0 принимается

# %%
# t-test для равенства средних
t_stat2, p_t2 = stats.ttest_ind(X1, X2, equal_var=False)

# F-test для равенства дисперсий
f_stat = np.var(X1, ddof=1) / np.var(X2, ddof=1)
df1, df2 = n1 - 1, n2 - 1
p_f = 2 * min(stats.f.cdf(f_stat, df1, df2), 1 - stats.f.cdf(f_stat, df1, df2))

pd.DataFrame({
    'Тест': ['2-sample t-test', '2-sample F-test'],
    'Статистика': [t_stat2, f_stat],
    'p-value': [p_t2, p_f],
    'Решение при α=0.05': [
        'H0 принимается' if p_t2 > alpha else 'H0 отвергается',
        'H0 принимается' if p_f > alpha else 'H0 отвергается'
    ]
})
# Out:
#               Тест  Статистика       p-value Решение при α=0.05
# 0  2-sample t-test    8.170060  1.595800e-13     H0 отвергается
# 1  2-sample F-test    4.513521  7.791545e-13     H0 отвергается

# %%
N = 1000
Z_values = []
p_values = []

for _ in range(N):
    sample = stats.norm.rvs(loc=m1_true, scale=sigma1_true, size=n1)
    z = (np.mean(sample) - m1_true) / (sigma1_true / np.sqrt(n1))
    p = 2 * (1 - stats.norm.cdf(abs(z)))
    Z_values.append(z)
    p_values.append(p)

# Теоретические распределения
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(Z_values, bins=30, density=True, alpha=0.6)
x = np.linspace(-4, 4, 200)
axes[0].plot(x, stats.norm.pdf(x), 'r', lw=2)
axes[0].set_title('Распределение статистики Z')

axes[1].hist(p_values, bins=20, density=True, alpha=0.6)
x = np.linspace(0, 1, 200)
axes[1].plot(x, np.ones_like(x), 'r', lw=2)
axes[1].set_title('Распределение p-value')

plt.show()
